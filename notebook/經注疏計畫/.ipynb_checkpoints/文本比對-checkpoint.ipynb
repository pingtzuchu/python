# %% [markdown]
# 1. 多文本
# 2. 把簡體版先繁體化
# 3. 去掉所有的標記
# 4. 進行比對
# 5. 只取insert

# %%
from difflib import SequenceMatcher
for i in range(1, 4):
    with open(r"G:\小組雲端硬碟\儒家經典注疏\十三經注疏\temp\temp1"+str(i).strip(), "r", encoding="utf8") as infile:
        strA = infile.read()
    with open(r"G:\小組雲端硬碟\儒家經典注疏\十三經注疏\temp\temp2"+str(i).strip(), "r", encoding="utf8") as infile:
        strB = infile.read()
    puntList="《》：，；「」。○、？·『』！（）"
    result=""
    start_i=0
    s = SequenceMatcher(None, strA, strB)
    for tag, i1, i2, j1, j2 in s.get_opcodes():
        tempPunt=""
        if tag == "insert":
            try:
                if strB[j1:j2].strip().find("<") > -1:
                    temp=strB[j1:j2].strip()[:strB[j1:j2].strip().find("<")]
                else:
                    temp=strB[j1:j2].strip()
                if len(temp) >0:
                    result += strA[start_i:i1]+temp
                    start_i = i1
            except:
                pass
    with open(r"G:\小組雲端硬碟\儒家經典注疏\十三經注疏\temp\temp3"+str(i).strip(), "w", encoding="utf8") as outfile:
        outfile.write(result)
    print(str(i))
print("We're done.")

# %% [markdown]
# 單文本

# %%
import time, datetime
from difflib import SequenceMatcher
start_time=time.time()
with open(r"G:\小組雲端硬碟\儒家經典注疏\十三經注疏\temp\Untitled1.xml", "r", encoding="utf8") as infile:
    fileA = infile.read().split("＃＃＄＄")
with open(r"G:\小組雲端硬碟\儒家經典注疏\十三經注疏\temp\Untitled2.xml", "r", encoding="utf8") as infile:
    fileB = infile.read().split("＃＃＄＄")
result=""
start_i=0
junkLetters=""" \t\n\r\fabcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789<>:'`;.?",
‘’‚“”„•‧․‥…、。〈〉[]《》「」『』（），、。．：？！－…；·：【】/
"""
print(len(fileA))
for i in range(len(fileA)):
    s = SequenceMatcher(lambda x: x in junkLetters, fileA[i], fileB[i], autojunk=False)
    strA=fileA[i]
    strB=fileB[i]
    for tag, i1, i2, j1, j2 in s.get_opcodes():
        result += strA[start_i:i1]
        if tag == "insert":
            for p in strB[j1:j2]:
                if p in "•‧․‥…、。〈〉[]《》「」『』（），．：？！－…：【】":
                    result += p
            start_i = i1
with open(r"G:\小組雲端硬碟\儒家經典注疏\十三經注疏\temp31", "w", encoding="utf8") as outfile:
    outfile.write(result)
print (datetime.datetime.now())
print(time.time()-start_time)

# %%
每次讀10行？

# %%
import time, datetime
from difflib import SequenceMatcher
start_time=time.time()
with open(r"G:\小組雲端硬碟\儒家經典注疏\十三經注疏\漢子電子文獻-刪校勘記\毛詩 - 複製.xml", "r", encoding="utf8") as infile:
    fileA = infile.read().split("＃＃＄＄")
with open(r"G:\小組雲端硬碟\儒家經典注疏\十三經注疏\網路簡體版\毛诗正义-t.xml", "r", encoding="utf8") as infile:
    fileB = infile.read().split("＃＃＄＄")
result=""
start_i=0
for i in range(len(fileA)):
    s = SequenceMatcher(None, fileA[i], fileB[i], autojunk=False)
    strA=fileA[i]
    strB=fileB[i]
    for tag, i1, i2, j1, j2 in s.get_opcodes():
        result += strA[start_i:i1]
        if tag == "insert":
            for p in strB[j1:j2]:
                if p in "‘’‚“”„•‧․‥…、。〈〉[]《》「」『』（），．：？！－…；·：【】":
                    result += p
        start_i = i1
    print (i)
with open(r"G:\小組雲端硬碟\儒家經典注疏\十三經注疏\temp31", "w", encoding="utf8") as outfile:
    outfile.write(result)
print (datetime.datetime.now())
print(time.time()-start_time)

# %% [markdown]
# 在文本中加入分段記號，然後分段處理。

# %%
import time, datetime
from difflib import SequenceMatcher
start_time=time.time()
with open(r"G:\小組雲端硬碟\儒家經典注疏\十三經注疏\網路簡體版\毛诗正义-t.xml", "r", 
          encoding="utf8") as file1:
    strA = file1.read().split("＃＃＄＄")
with open(r"G:\小組雲端硬碟\儒家經典注疏\十三經注疏\漢子電子文獻-刪校勘記\毛詩 - 複製.xml", "r",
          encoding="utf8") as file2:
    strB = file2.read().split("＃＃＄＄")
finalResult = ""
def compareTwoString(strA, strB):
    result=""
    junkLetters="、。〈〉[]《》「」『』（），、。．：？！－…；·：【】"
    start_i=0
    end_i=0
    s = SequenceMatcher(None, strA, strB, autojunk=False)
    for tag, i1, i2, j1, j2 in s.get_opcodes():
        repStr = strB[j1:j2].strip()
        if (tag == "replace") and len(repStr) > 0:
            result += strA[start_i:i1]
            index = 0
            for c in strA[i1:i2]:
                if not(c > u'\u4e000' and c < u'\u9fff'):
                    result+= c
                else:
                    try:
                        result += repStr[index]
                        index += 1
                    except:
                        pass
            try:
                if c in repStr[index:]:
                    result += repStr[index:]
            except:
                pass
            start_i=i2
            print(i2)
        elif tag == "insert" and len(repStr) > 0 and len(repStr)<3:
            result += strA[start_i:i1]+repStr
            start_i = i1
    result += strA[start_i:]
    return result
for i in range(len(strA)):
    finalResult += compareTwoString(strA[i], strB[i])
    print(i)   
with open(r"G:\小組雲端硬碟\儒家經典注疏\十三經注疏\temp\finalResult.xml", "w", encoding="utf8") as outfile:
    outfile.write(finalResult)
print (datetime.datetime.now())
print(time.time()-start_time)
# Out:
# 9
# 31
# 40
# 47
# 53
# 74
# 76
# 90
# 119
# 122
# 137
# 164
# 206
# 240
# 262
# 276
# 295
# 324
# 353
# 374
# 382
# 385
# 391
# 403
# 424
# 453
# 466
# 479
# 486
# 501
# 504
# 509
# 518
# 601
# 608
# 611
# 628
# 657
# 672
# 677
# 688
# 698
# 720
# 734
# 743
# 854
# 867
# 890
# 927
# 950
# 1014
# 1093
# 1243
# 1255
# 1287
# 1302
# 1306
# 1317
# 1338
# 1355
# 1404
# 1515
# 1546
# 1557
# 1570
# 1620
# 1639
# 1672
# 1706
# 1745
# 1813
# 1852
# 1883
# 1928
# 2038
# 2048
# 2105
# 2115
# 2207
# 2227
# 2262
# 2333
# 2349
# 2354
# 2359
# 2502
# 2517
# 2611
# 2642
# 2664
# 2697
# 2709
# 2717
# 2736
# 2745
# 2855
# 2869
# 2898
# 3023
# 3081
# 3099
# 3108
# 3165
# 3171
# 3177
# 3208
# 3231
# 3236
# 3249
# 3279
# 3304
# 3376
# 3405
# 3422
# 3477
# 3488
# 3574
# 3630
# 3640
# 3642
# 3680
# 3690
# 3769
# 3774
# 3824
# 3893
# 3944
# 3963
# 4041
# 4062
# 4116
# 4312
# 4432
# 4473
# 4502
# 4507
# 4540
# 4707
# 4714
# 4745
# 4750
# 4835
# 4840
# 4856
# 4933
# 4951
# 4959
# 4970
# 5001
# 5024
# 5084
# ...

# %%
import time
from difflib import SequenceMatcher
start_time=time.time()
with open(r"G:\小組雲端硬碟\儒家經典注疏\十三經注疏\temp\temp11", "r", encoding="utf8") as infile:
    strA = infile.read()
with open(r"G:\小組雲端硬碟\儒家經典注疏\十三經注疏\temp\temp21", "r", encoding="utf8") as infile:
    strB = infile.read()
finalResult = "比較\t原字詞\t取代字詞\n"
junkLetters=""" \t\n\r\fabcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789<>:'`;.?",
‘’‚“”„•‧․‥…、。〈〉[]《》「」『』（），、。．：？！－…；·：{}【】/
"""
s = SequenceMatcher(lambda x: x in letters, strA, strB, autojunk=False)
for tag, i1, i2, j1, j2 in s.get_opcodes():
    if tag=="replace":
        finalResult += tag + "\t" + strA[i1:i2]+"\t"+strB[j1:j2]+"\n"
with open(r"G:\小組雲端硬碟\儒家經典注疏\十三經注疏\temp\finalResult.xml", "w", encoding="utf8") as outfile:
    outfile.write(finalResult)
print(time.time()-start_time)

# %%
print("Is it running?")

# %%
import time, datetime
from difflib import SequenceMatcher
start_time=time.time()
with open(r"G:\小組雲端硬碟\儒家經典注疏\十三經注疏\temp\Untitled1.xml", "r", encoding="utf8") as infile:
    fileA = infile.read()
with open(r"G:\小組雲端硬碟\儒家經典注疏\十三經注疏\temp\Untitled2.xml", "r", encoding="utf8") as infile:
    fileB = infile.read()
finalResult = ""
junkLetters=""" \t\n\r\fabcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789<>:'`;.?",
‘’‚“”„•‧․‥…、。〈〉[]《》「」『』（），、。．：？！－…；·：{}【】/
"""
start_i=0
s = SequenceMatcher(lambda x: x in junkLetters, fileA[:50000], fileB[:50000], autojunk=False)
for tag, i1, i2, j1, j2 in s.get_opcodes():
    if tag=="insert":
        finalResult += fileA[:50000][start_i:i1]
        for p in fileB[:50000][j1:j2]:
            if p in "‘’‚“”„•‧․‥…、。〈〉[]《》「」『』，．：？！－…；·：【】":
                finalResult += p
        start_i=i1
print(finalResult)
print(time.time()-start_time)

# %%
import time, datetime, re
from difflib import SequenceMatcher
start_time=time.time()
with open(r"G:\小組雲端硬碟\儒家經典注疏\十三經注疏\temp\Untitled1.xml", "r", encoding="utf8") as infile:
    fileA = infile.read().split("＃＃＄＄")
with open(r"G:\小組雲端硬碟\儒家經典注疏\十三經注疏\temp\Untitled2.xml", "r", encoding="utf8") as infile:
    fileB = infile.read().split("＃＃＄＄")
result=""
start_i=0
junkLetters=""" abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789<>:'`;.?"/{}[],‘’‚“”„
"""
print(len(fileA))
def insertPunt(strA, strB):
    chin=re.findall(u'[\u4e00-\u9fff]+', strB)
    if len(chin)==0:
        return strB+strA
    elif len(chin)==1:
        if strB.find(chin[0])==0:
            return strA+strB[len(chin[0]):]
        else:
            return strB[:len(chin[0])]+strA
    elif len(chin)==2:
        return strA[:len(chin[0])] + strB[len(chin[0]):len(strB)-len(chin[1])-len(chin[0])] + strA[len(chin[0]):]
result = ""
for i in range(len(fileA)):
    strA=fileA[i]
    strB=fileB[i]
    s = SequenceMatcher(lambda x: x in junkLetters, strA, strB, autojunk=False)
    for tag, i1, i2, j1, j2 in s.get_opcodes():
        try:
            if tag=="replace":
                result += strA[start_i:i1]+insertPunt(strA[i1:i2], strB[j1:j2].strip())
                start_i = i2
            elif tag=="insert":
                result += strA[start_i:i1]+strB[j1:j2].strip()
                start_i=i1
        except:
            pass
with open(r"G:\小組雲端硬碟\儒家經典注疏\十三經注疏\temp32.xml", "w", encoding="utf8") as outfile:
    outfile.write(result)
print (datetime.datetime.now())
print(time.time()-start_time)

# %%
import re
ipath= "，。"
print (re.findall(u'[\u4e00-\u9fff]+', ipath))

# %%
strA ="AACCBB"
strB="AACC"
print(strA-strB)
